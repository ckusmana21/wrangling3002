# %% [markdown]
# <a href="https://colab.research.google.com/github/ckusmana21/wrangling3002/blob/main/3002_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **QUESTION 2** (Note: Question 3 answers are at the end)

# %% [markdown]
# 2.1

# %%
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.read_csv('/content/airbnb_hw.csv')
print( df.shape, '\n')
df.head()

price = df['Price']
price.unique()

# Converting to numeric
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

# Removing NAs
df = df.dropna(subset=['Price'])
# Out:
# (30478, 13)

# %% [markdown]
# 2.2

# %%
import pandas as pd

df = pd.read_csv('/content/sharks.csv')

# Here, I'm standardizing the entries
df['Type'] = df['Type'].str.lower().str.strip()

# Here, I'm removing missing values in Type
df = df.dropna(subset=['Type'])
# Out:
# <ipython-input-4-5fd40fdf41d8>:3: DtypeWarning: Columns (10,17,18,19,20,21,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/sharks.csv')

# %% [markdown]
# 2.3

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/pretrial_data.csv')

df.head()

# Removing missing values (I wasn't able to pull the column WhetherDefendantWasReleasedPretrial, so I left the script for removing NAs as comments.)
## df['WhetherDefendantWasReleasedPretrial'].replace('', np.nan, inplace=True)
## df['WhetherDefendantWasReleasedPretrial'].replace('unknown', np.nan, inplace=True)
# Out:
# <ipython-input-9-08aa413299db>:4: DtypeWarning: Columns (2,5,6,8,80,81,82,83,84,85,109,164,165,166,167,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,271,272,273,274,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,302,303,304,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,367,368,369,370,371,372,373,374,375,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399
# ...

# %% [markdown]
# **QUESTION 3**

# %% [markdown]
# 1. According to census.gov, since July 2021, the survey also covers questions about sexual orientation and gender identity as a part of the Household Pulse Survey. The options for assigned gender at birth are Male or Female; the options for "Do you currently describe yourself as male, female or transgender" are male, female, transgender, or none of these; the options for sexual orientation are Gay or lesbian; Straight, that is not gay or lesbian; Bisexual; Something else; I don’t know. As for race, respondents are able to self-identify and select more than one categories that best reflect their racial identity.
#
# 2. I think collecting demographic data is important especially for policymakers, who will be better informed about the needs and challenges faced by certain population, as well as how their identity impact them. The data also helps researchers and the public alike understand trends relating to race, gender, and sexuality -- perhaps by comparing them to data from pervious years to capture how diversity has grown over the year in the US.
#
# 3. I think it is great that the census allows respondents to select more than one options for race, as it recognizes multiracial identities.
#
# 4. However, I thought the options for gender identity could have been more granular: for example, providing non-binary and other gender identites as the categories.
#
# 5. I think protected characteristics (race, gender, sexual identites) are complex, so their nuances may not he fully captured by a binary/more simplified data structure. Removing NAs and cleaning the data may also erase intersectionality in the data. In particular, methods like imputation or dropping NAs may lead to underrepresentation of certain group and skew the result of the analysis, as well as introducing bias. There is privacy concern regarding whether sensitive data that is linked to personally identifiable information could inadvertently be explosed, leading to data breaches.
#
# 6. I believe imputation would not be a good method for data cleaning, because there is just no "average" response to, for instance, sexual identity, and filling the gaps in this way seems misleading and unethical. This ignores intersectionality; furthermore, imputation would likely rely on historical data that forces individuals into pre-defined categores, which leads to incorrect conclusions that erase the identities of minority groups. I think protected characteristics are complex and it cannot be reduced to a "pattern"; but in addition to technical and practical concerns, individuals involved may not have given consent for an imputation to take place, which would violate their privacy. Challenging the results of the imputed data would also be difficult, as there is no way of telling which result is correct or wrong, given the "black box" nature of most imputation algorithms.
